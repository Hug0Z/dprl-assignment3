# %%
import random

import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
V = np.genfromtxt('conv2.csv', delimiter=',')

# %%
total_data = V[:,1]
total_run = V[:,0]

# %%
plot = sb.lineplot(data=total_data[:100])
fig = plot.get_figure()
plt.xlabel("Iteration")
plt.ylabel("Q value")
plt.title("Q value towards convergence")
plt.show(fig)
fig.savefig("conv_first2.pdf")
fig.clf()

# %%
plot = sb.lineplot(data=total_data[10000:])
fig = plot.get_figure()
plt.xlabel("Iteration")
plt.ylabel("Q value")
plt.title("Q value towards convergence")
plt.show(fig)
fig.savefig("conv_after2.pdf")
fig.clf()
